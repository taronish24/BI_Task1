# %%
### keras and Tenserflow > 2.0

# %%
# Data collection 
import pandas as pd

# %%
df = pd.read_csv('MSFT.csv')

df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1986-03-13    0.088542    0.101563    0.088542    0.097222    0.060524
# 1     1986-03-14    0.097222    0.102431    0.097222    0.100694    0.062686
# 2     1986-03-17    0.100694    0.103299    0.100694    0.102431    0.063767
# 3     1986-03-18    0.102431    0.103299    0.098958    0.099826    0.062145
# 4     1986-03-19    0.099826    0.100694    0.097222    0.098090    0.061065
# ...          ...         ...         ...         ...         ...         ...
# 9409  2023-07-14  347.589996  351.429993  344.309998  345.239990  345.239990
# 9410  2023-07-17  345.679993  346.989990  342.200012  345.730011  345.730011
# 9411  2023-07-18  345.829987  366.779999  342.170013  359.489990  359.489990
# 9412  2023-07-19  361.750000  362.459991  352.440002  355.079987  355.079987
# 9413  2023-07-20  353.570007  357.970001  345.369995  346.869995  346.869995
#
#           Volume
# 0     1031788800
# 1      308160000
# 2      133171200
# 3       67766400
# 4       47894400
# ...          ...
# 9409    28302200
# 9410    20363900
# 9411    64872700
# 9412    39732900
# 9413    33678000
#
# [9414 rows x 7 columns]

# %%
df = df[["Date","Close"]]

# %%
df['Date']
# Out:
# 0       1986-03-13
# 1       1986-03-14
# 2       1986-03-17
# 3       1986-03-18
# 4       1986-03-19
#            ...
# 9409    2023-07-14
# 9410    2023-07-17
# 9411    2023-07-18
# 9412    2023-07-19
# 9413    2023-07-20
# Name: Date, Length: 9414, dtype: object

# %%
import datetime

# %%
def str_to_datetime(s):
    split = s.split("-")
    year,month,day = int(split[0]),int(split[1]),int(split[2])
    return datetime.datetime(year=year,month=month,day=day)

# %%
datetime_object = str_to_datetime('1986-03-19')
datetime_object
# Out:
# datetime.datetime(1986, 3, 19, 0, 0)

# %%
df["Date"]= df["Date"].apply(str_to_datetime)
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_2180\1118745636.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Date"]= df["Date"].apply(str_to_datetime)

# %%
df.index = df.pop("Date")

# %%
df
# Out:
#                  Close
# Date
# 1986-03-13    0.097222
# 1986-03-14    0.100694
# 1986-03-17    0.102431
# 1986-03-18    0.099826
# 1986-03-19    0.098090
# ...                ...
# 2023-07-14  345.239990
# 2023-07-17  345.730011
# 2023-07-18  359.489990
# 2023-07-19  355.079987
# 2023-07-20  346.869995
#
# [9414 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
plt.plot(df)

# %%
import numpy as np

# %%
def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=3):
  first_date = str_to_datetime(first_date_str)
  last_date  = str_to_datetime(last_date_str)

  target_date = first_date

  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+1)

    if len(df_subset) != n+1:
      print(f'Warning: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))

    if last_time:
      break

    target_date = next_date

    if target_date == last_date:
      last_time = True

  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates

  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_df[f'Target-{n-i}'] = X[:, i]

  ret_df['Target'] = Y

  return ret_df

# %%
windowed_df = df_to_windowed_df(df,
                                '2021-03-25', 
                                '2022-03-23',
                                n=3)
windowed_df
# Out:
#     Target Date    Target-3    Target-2    Target-1      Target
# 0    2021-03-25  235.990005  237.580002  235.460007  232.339996
# 1    2021-03-26  237.580002  235.460007  232.339996  236.479996
# 2    2021-03-29  235.460007  232.339996  236.479996  235.240005
# 3    2021-03-30  232.339996  236.479996  235.240005  231.850006
# 4    2021-03-31  236.479996  235.240005  231.850006  235.770004
# ..          ...         ...         ...         ...         ...
# 247  2022-03-17  276.440002  287.149994  294.390015  295.220001
# 248  2022-03-18  287.149994  294.390015  295.220001  300.429993
# 249  2022-03-21  294.390015  295.220001  300.429993  299.160004
# 250  2022-03-22  295.220001  300.429993  299.160004  304.059998
# 251  2022-03-23  300.429993  299.160004  304.059998  299.489990
#
# [252 rows x 5 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape

q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

# %%
model = Sequential([layers.Input((3, 1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

# %%
model.compile(loss='mse',
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

# %%
model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 6s 162ms/step - loss: 84163.7500 - mean_absolute_error: 288.3658 - val_loss: 91744.0312 - val_mean_absolute_error: 302.8053
# Epoch 2/100
# 7/7 [==============================] - 0s 13ms/step - loss: 83783.4453 - mean_absolute_error: 287.7033 - val_loss: 91312.7109 - val_mean_absolute_error: 302.0922
# Epoch 3/100
# 7/7 [==============================] - 0s 13ms/step - loss: 83330.1016 - mean_absolute_error: 286.9125 - val_loss: 90764.1484 - val_mean_absolute_error: 301.1829
# Epoch 4/100
# 7/7 [==============================] - 0s 14ms/step - loss: 82760.4844 - mean_absolute_error: 285.9209 - val_loss: 90070.2188 - val_mean_absolute_error: 300.0287
# Epoch 5/100
# 7/7 [==============================] - 0s 12ms/step - loss: 82044.2734 - mean_absolute_error: 284.6594 - val_loss: 89237.2188 - val_mean_absolute_error: 298.6372
# Epoch 6/100
# 7/7 [==============================] - 0s 15ms/step - loss: 81135.7188 - mean_absolute_error: 283.0580 - val_loss: 87994.4297 - val_mean_absolute_error: 296.5491
# Epoch 7/100
# 7/7 [==============================] - 0s 13ms/step - loss: 79770.0781 - mean_absolute_error: 280.6289 - val_loss: 86282.5000 - val_mean_absolute_error: 293.6486
# Epoch 8/100
# 7/7 [==============================] - 0s 12ms/step - loss: 78155.0156 - mean_absolute_error: 277.7492 - val_loss: 84599.2969 - val_mean_absolute_error: 290.7684
# Epoch 9/100
# 7/7 [==============================] - 0s 11ms/step - loss: 76402.1875 - mean_absolute_error: 274.5802 - val_loss: 82424.9062 - val_mean_absolute_error: 287.0049
# Epoch 10/100
# 7/7 [==============================] - 0s 12ms/step - loss: 73995.0938 - mean_absolute_error: 270.1569 - val_loss: 79282.9609 - val_mean_absolute_error: 281.4782
# Epoch 11/100
# 7/7 [==============================] - 0s 12ms/step - loss: 70949.2500 - mean_absolute_error: 264.4504 - val_loss: 76037.5234 - val_mean_absolute_error: 275.6530
# Epoch 12/100
# 7/7 [==============================] - 0s 13ms/step - loss: 67826.4141 - mean_absolute_error: 258.4717 - val_loss: 72578.3828 - val_mean_absolute_error: 269.3055
# Epoch 13/100
# 7/7 [==============================] - 0s 13ms/step - loss: 64409.0156 - mean_absolute_error: 251.7947 - val_loss: 68714.3516 - val_mean_absolute_error: 262.0331
# Epoch 14/100
# 7/7 [==============================] - 0s 12ms/step - loss: 60566.2383 - mean_absolute_error: 244.0318 - val_loss: 64162.1094 - val_mean_absolute_error: 253.1976
# Epoch 15/100
# 7/7 [==============================] - 0s 11ms/step - loss: 55904.8477 - mean_absolute_error: 234.2504 - val_loss: 58817.7969 - val_mean_absolute_error: 242.4144
# Epoch 16/100
# 7/7 [==============================] - 0s 15ms/step - loss: 50705.3516 - mean_absolute_error: 222.9406 - val_loss: 52858.3281 - val_mean_absolute_error: 229.7942
# Epoch 17/100
# 7/7 [==============================] - 0s 14ms/step - loss: 45173.3242 - mean_absolute_error: 210.1299 - val_loss: 47095.6914 - val_mean_absolute_error: 216.8932
# Epoch 18/100
# 7/7 [==============================] - 0s 12ms/step - loss: 39646.3203 - mean_absolute_error: 196.4963 - val_loss: 40829.1484 - val_mean_absolute_error: 201.9311
# Epoch 19/100
# 7/7 [==============================] - 0s 12ms/step - loss: 33951.5508 - mean_absolute_error: 181.3762 - val_loss: 34917.1328 - val_mean_absolute_error: 186.7195
# Epoch 20/100
# 7/7 [==============================] - 0s 12ms/step - loss: 28545.9531 - mean_absolute_error: 165.8547 - val_loss: 29178.3516 - val_mean_absolute_error: 170.6616
# Epoch 21/100
# 7/7 [==============================] - 0s 18ms/step - loss: 23394.4082 - mean_absolute_error: 149.4766 - val_loss: 23710.6875 - val_mean_absolute_error: 153.8106
# Epoch 22/100
# 7/7 [==============================] - 0s 13ms/step - loss: 18502.0625 - mean_absolute_error: 132.2129 - val_loss: 18285.5039 - val_mean_absolute_error: 135.0264
# Epoch 23/100
# 7/7 [==============================] - 0s 12ms/step - loss: 13576.1924 - mean_absolute_error: 111.9473 - val_loss: 13132.0820 - val_mean_absolute_error: 114.3627
# Epoch 24/100
# 7/7 [==============================] - 0s 10ms/step - loss: 9516.2812 - mean_absolute_error: 91.9694 - val_loss: 9151.7539 - val_mean_absolute_error: 95.3876
# Epoch 25/100
# 7/7 [==============================] - 0s 12ms/step - loss: 6507.6074 - mean_absolute_error: 74.0231 - val_loss: 6209.4131 - val_mean_absolute_error: 78.4630
# Epoch 26/100
# 7/7 [==============================] - 0s 11ms/step - loss: 4343.3369 - mean_absolute_error: 57.5891 - val_loss: 3987.6890 - val_mean_absolute_error: 62.7252
# Epoch 27/100
# 7/7 [==============================] - 0s 12ms/step - loss: 2741.1497 - mean_absolute_error: 42.8344 - val_loss: 2227.1416 - val_mean_absolute_error: 46.6253
# Epoch 28/100
# 7/7 [==============================] - 0s 12ms/step - loss: 1724.4103 - mean_absolute_error: 33.8543 - val_loss: 1174.5092 - val_mean_absolute_error: 33.4865
# Epoch 29/100
# 7/7 [==============================] - 0s 12ms/step - loss: 1212.0526 - mean_absolute_error: 29.4910 - val_loss: 512.8482 - val_mean_absolute_error: 21.4460
# Epoch 30/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1026.4860 - mean_absolute_error: 27.0950 - val_loss: 280.3093 - val_mean_absolute_error: 15.1297
# Epoch 31/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1017.5011 - mean_absolute_error: 27.0059 - val_loss: 231.8064 - val_mean_absolute_error: 13.5617
# Epoch 32/100
# 7/7 [==============================] - 0s 12ms/step - loss: 1011.9667 - mean_absolute_error: 26.8995 - val_loss: 211.8628 - val_mean_absolute_error: 12.8582
# Epoch 33/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1013.3221 - mean_absolute_error: 26.9211 - val_loss: 215.6662 - val_mean_absolute_error: 12.9978
# Epoch 34/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1006.4619 - mean_absolute_error: 26.8196 - val_loss: 224.3195 - val_mean_absolute_error: 13.3075
# Epoch 35/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1001.4468 - mean_absolute_error: 26.7417 - val_loss: 255.9948 - val_mean_absolute_error: 14.3734
# Epoch 36/100
# 7/7 [==============================] - 0s 11ms/step - loss: 1001.0760 - mean_absolute_error: 26.7702 - val_loss: 268.0250 - val_mean_absolute_error: 14.7576
# Epoch 37/100
# 7/7 [==============================] - 0s 10ms/step - loss: 995.9280 - mean_absolute_error: 26.6671 - val_loss: 266.1585 - val_mean_absolute_error: 14.6994
# Epoch 38/100
# 7/7 [==============================] - 0s 10ms/step - loss: 993.9172 - mean_absolute_error: 26.6524 - val_loss: 283.2556 - val_mean_absolute_error: 15.2293
# Epoch 39/100
# 7/7 [==============================] - 0s 10ms/step - loss: 992.2820 - mean_absolute_error: 26.6211 - val_loss: 269.4995 - val_mean_absolute_error: 14.8065
# Epoch 40/100
# 7/7 [==============================] - 0s 9ms/step - loss: 994.5062 - mean_absolute_error: 26.6628 - val_loss: 246.8481 - val_mean_absolute_error: 14.0792
# Epoch 41/100
# 7/7 [==============================] - 0s 11ms/step - loss: 988.1204 - mean_absolute_error: 26.5664 - val_loss: 277.8004 - val_mean_absolute_error: 15.0677
# Epoch 42/100
# 7/7 [==============================] - 0s 10ms/step - loss: 986.0767 - mean_absolute_error: 26.5724 - val_loss: 255.5807 - val_mean_absolute_error: 14.3718
# Epoch 43/100
# 7/7 [==============================] - 0s 10ms/step - loss: 978.6793 - mean_absolute_error: 26.4352 - val_loss: 265.4869 - val_mean_absolute_error: 14.6971
# Epoch 44/100
# 7/7 [==============================] - 0s 10ms/step - loss: 957.8867 - mean_absolute_error: 26.1115 - val_loss: 281.1985 - val_mean_absolute_error: 15.1973
# Epoch 45/100
# 7/7 [==============================] - 0s 10ms/step - loss: 939.8187 - mean_absolute_error: 25.8209 - val_loss: 323.8485 - val_mean_absolute_error: 16.5494
# Epoch 46/100
# 7/7 [==============================] - 0s 9ms/step - loss: 912.2565 - mean_absolute_error: 25.4993 - val_loss: 295.4663 - val_mean_absolute_error: 15.6910
# Epoch 47/100
# 7/7 [==============================] - 0s 10ms/step - loss: 889.2194 - mean_absolute_error: 25.2470 - val_loss: 263.1269 - val_mean_absolute_error: 14.6841
# Epoch 48/100
# 7/7 [==============================] - 0s 10ms/step - loss: 863.5324 - mean_absolute_error: 24.7486 - val_loss: 284.7532 - val_mean_absolute_error: 15.3977
# Epoch 49/100
# 7/7 [==============================] - 0s 9ms/step - loss: 826.7482 - mean_absolute_error: 24.2619 - val_loss: 490.4101 - val_mean_absolute_error: 21.1667
# Epoch 50/100
# 7/7 [==============================] - 0s 9ms/step - loss: 819.7316 - mean_absolute_error: 24.0072 - val_loss: 116.9788 - val_mean_absolute_error: 8.9081
# Epoch 51/100
# 7/7 [==============================] - 0s 9ms/step - loss: 819.0414 - mean_absolute_error: 23.8598 - val_loss: 190.6062 - val_mean_absolute_error: 12.2626
# Epoch 52/100
# 7/7 [==============================] - 0s 9ms/step - loss: 740.7017 - mean_absolute_error: 22.8931 - val_loss: 282.3515 - val_mean_absolute_error: 15.4372
# Epoch 53/100
# 7/7 [==============================] - 0s 10ms/step - loss: 735.2700 - mean_absolute_error: 22.9499 - val_loss: 112.3071 - val_mean_absolute_error: 8.7656
# Epoch 54/100
# 7/7 [==============================] - 0s 10ms/step - loss: 740.2557 - mean_absolute_error: 22.7162 - val_loss: 417.1567 - val_mean_absolute_error: 19.3396
# Epoch 55/100
# 7/7 [==============================] - 0s 10ms/step - loss: 706.2080 - mean_absolute_error: 22.4403 - val_loss: 238.2430 - val_mean_absolute_error: 14.0086
# Epoch 56/100
# 7/7 [==============================] - 0s 9ms/step - loss: 680.5098 - mean_absolute_error: 22.0927 - val_loss: 291.1842 - val_mean_absolute_error: 15.8048
# Epoch 57/100
# 7/7 [==============================] - 0s 10ms/step - loss: 641.9483 - mean_absolute_error: 21.3882 - val_loss: 142.0874 - val_mean_absolute_error: 10.3474
# Epoch 58/100
# 7/7 [==============================] - 0s 9ms/step - loss: 648.4993 - mean_absolute_error: 21.5024 - val_loss: 160.7764 - val_mean_absolute_error: 11.2006
# Epoch 59/100
# 7/7 [==============================] - 0s 9ms/step - loss: 626.7432 - mean_absolute_error: 21.1183 - val_loss: 290.8916 - val_mean_absolute_error: 15.8681
# Epoch 60/100
# 7/7 [==============================] - 0s 9ms/step - loss: 620.0319 - mean_absolute_error: 20.6849 - val_loss: 79.8073 - val_mean_absolute_error: 7.2262
# Epoch 61/100
# 7/7 [==============================] - 0s 9ms/step - loss: 576.5423 - mean_absolute_error: 20.2776 - val_loss: 188.7076 - val_mean_absolute_error: 12.3476
# Epoch 62/100
# 7/7 [==============================] - 0s 10ms/step - loss: 539.1573 - mean_absolute_error: 19.5447 - val_loss: 374.7668 - val_mean_absolute_error: 18.3842
# Epoch 63/100
# 7/7 [==============================] - 0s 10ms/step - loss: 578.4544 - mean_absolute_error: 20.3162 - val_loss: 78.9557 - val_mean_absolute_error: 7.2110
# Epoch 64/100
# 7/7 [==============================] - 0s 10ms/step - loss: 468.2198 - mean_absolute_error: 18.2538 - val_loss: 102.8879 - val_mean_absolute_error: 8.5603
# Epoch 65/100
# 7/7 [==============================] - 0s 12ms/step - loss: 407.5611 - mean_absolute_error: 16.8333 - val_loss: 144.6653 - val_mean_absolute_error: 10.6376
# Epoch 66/100
# 7/7 [==============================] - 0s 15ms/step - loss: 369.2654 - mean_absolute_error: 15.9331 - val_loss: 133.5804 - val_mean_absolute_error: 10.1539
# Epoch 67/100
# 7/7 [==============================] - 0s 13ms/step - loss: 322.8616 - mean_absolute_error: 14.8898 - val_loss: 416.8264 - val_mean_absolute_error: 19.6040
# Epoch 68/100
# 7/7 [==============================] - 0s 12ms/step - loss: 345.3434 - mean_absolute_error: 15.1819 - val_loss: 75.6756 - val_mean_absolute_error: 7.1425
# Epoch 69/100
# 7/7 [==============================] - 0s 13ms/step - loss: 258.1534 - mean_absolute_error: 13.0161 - val_loss: 61.1779 - val_mean_absolute_error: 6.3177
# Epoch 70/100
# 7/7 [==============================] - 0s 10ms/step - loss: 229.3040 - mean_absolute_error: 12.2522 - val_loss: 35.7140 - val_mean_absolute_error: 5.0930
# Epoch 71/100
# 7/7 [==============================] - 0s 12ms/step - loss: 211.3156 - mean_absolute_error: 11.8069 - val_loss: 38.6589 - val_mean_absolute_error: 5.2485
# Epoch 72/100
# 7/7 [==============================] - 0s 11ms/step - loss: 176.4476 - mean_absolute_error: 10.7950 - val_loss: 32.0146 - val_mean_absolute_error: 4.9625
# Epoch 73/100
# 7/7 [==============================] - 0s 10ms/step - loss: 156.9037 - mean_absolute_error: 9.9611 - val_loss: 33.2218 - val_mean_absolute_error: 4.8928
# Epoch 74/100
# 7/7 [==============================] - 0s 9ms/step - loss: 144.7682 - mean_absolute_error: 9.5062 - val_loss: 61.5881 - val_mean_absolute_error: 6.2732
# Epoch 75/100
# 7/7 [==============================] - 0s 11ms/step - loss: 152.5504 - mean_absolute_error: 10.0233 - val_loss: 37.2478 - val_mean_absolute_error: 5.0350
# Epoch 76/100
# 7/7 [==============================] - 0s 9ms/step - loss: 91.9144 - mean_absolute_error: 7.3013 - val_loss: 30.3876 - val_mean_absolute_error: 4.8473
# Epoch 77/100
# 7/7 [==============================] - 0s 11ms/step - loss: 66.2300 - mean_absolute_error: 6.0227 - val_loss: 58.2821 - val_mean_absolute_error: 6.0273
# Epoch 78/100
# 7/7 [==============================] - 0s 18ms/step - loss: 54.8491 - mean_absolute_error: 5.8817 - val_loss: 33.5540 - val_mean_absolute_error: 5.0476
# Epoch 79/100
# 7/7 [==============================] - 0s 11ms/step - loss: 51.8636 - mean_absolute_error: 5.4906 - val_loss: 67.7207 - val_mean_absolute_error: 6.5495
# Epoch 80/100
# 7/7 [==============================] - 0s 9ms/step - loss: 62.0182 - mean_absolute_error: 6.5957 - val_loss: 58.2909 - val_mean_absolute_error: 6.0076
# Epoch 81/100
# 7/7 [==============================] - 0s 10ms/step - loss: 38.2540 - mean_absolute_error: 4.7908 - val_loss: 31.2010 - val_mean_absolute_error: 4.8021
# Epoch 82/100
# 7/7 [==============================] - 0s 10ms/step - loss: 36.8952 - mean_absolute_error: 4.5179 - val_loss: 57.5674 - val_mean_absolute_error: 5.9586
# Epoch 83/100
# 7/7 [==============================] - 0s 11ms/step - loss: 34.3822 - mean_absolute_error: 4.6830 - val_loss: 56.4866 - val_mean_absolute_error: 5.9065
# Epoch 84/100
# 7/7 [==============================] - 0s 13ms/step - loss: 31.0455 - mean_absolute_error: 4.3492 - val_loss: 43.4723 - val_mean_absolute_error: 5.2457
# Epoch 85/100
# 7/7 [==============================] - 0s 13ms/step - loss: 29.2727 - mean_absolute_error: 4.2024 - val_loss: 70.2072 - val_mean_absolute_error: 6.6630
# Epoch 86/100
# 7/7 [==============================] - 0s 13ms/step - loss: 29.2296 - mean_absolute_error: 4.3142 - val_loss: 69.0117 - val_mean_absolute_error: 6.5829
# Epoch 87/100
# 7/7 [==============================] - 0s 12ms/step - loss: 34.6378 - mean_absolute_error: 4.7842 - val_loss: 51.5939 - val_mean_absolute_error: 5.6923
# Epoch 88/100
# 7/7 [==============================] - 0s 11ms/step - loss: 25.4453 - mean_absolute_error: 3.9504 - val_loss: 105.9774 - val_mean_absolute_error: 8.7232
# Epoch 89/100
# 7/7 [==============================] - 0s 14ms/step - loss: 29.9946 - mean_absolute_error: 4.3557 - val_loss: 53.8767 - val_mean_absolute_error: 5.8312
# Epoch 90/100
# 7/7 [==============================] - 0s 14ms/step - loss: 22.2127 - mean_absolute_error: 3.6886 - val_loss: 37.6945 - val_mean_absolute_error: 4.9240
# Epoch 91/100
# 7/7 [==============================] - 0s 14ms/step - loss: 23.6296 - mean_absolute_error: 3.8522 - val_loss: 78.4363 - val_mean_absolute_error: 7.1875
# Epoch 92/100
# 7/7 [==============================] - 0s 12ms/step - loss: 29.2841 - mean_absolute_error: 4.2525 - val_loss: 45.9106 - val_mean_absolute_error: 5.4277
# Epoch 93/100
# 7/7 [==============================] - 0s 11ms/step - loss: 29.8217 - mean_absolute_error: 4.3776 - val_loss: 35.5234 - val_mean_absolute_error: 5.0817
# Epoch 94/100
# 7/7 [==============================] - 0s 12ms/step - loss: 28.2442 - mean_absolute_error: 4.3720 - val_loss: 32.2773 - val_mean_absolute_error: 4.7625
# Epoch 95/100
# 7/7 [==============================] - 0s 11ms/step - loss: 26.1869 - mean_absolute_error: 4.0199 - val_loss: 48.8994 - val_mean_absolute_error: 5.5922
# Epoch 96/100
# 7/7 [==============================] - 0s 11ms/step - loss: 21.9753 - mean_absolute_error: 3.7045 - val_loss: 56.0003 - val_mean_absolute_error: 5.9512
# Epoch 97/100
# 7/7 [==============================] - 0s 12ms/step - loss: 20.4316 - mean_absolute_error: 3.5985 - val_loss: 32.5919 - val_mean_absolute_error: 4.7595
# Epoch 98/100
# 7/7 [==============================] - 0s 12ms/step - loss: 26.4275 - mean_absolute_error: 4.1051 - val_loss: 38.6123 - val_mean_absolute_error: 4.9658
# Epoch 99/100
# 7/7 [==============================] - 0s 11ms/step - loss: 27.6483 - mean_absolute_error: 4.1020 - val_loss: 79.0371 - val_mean_absolute_error: 7.2150
# Epoch 100/100
# 7/7 [==============================] - 0s 12ms/step - loss: 28.6201 - mean_absolute_error: 4.2680 - val_loss: 110.5459 - val_mean_absolute_error: 8.9474

# %%
train_predictions = model.predict(X_train).flatten()
# Out:
# 7/7 [==============================] - 1s 3ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])

# %%
val_predictions = model.predict(X_val).flatten()
# Out:
# 1/1 [==============================] - 0s 29ms/step

# %%
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])

# %%
test_predictions = model.predict(X_test).flatten()
# Out:
# 1/1 [==============================] - 0s 30ms/step

# %%
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations'])

# %%
from copy import deepcopy

# %%
recursive_predictions = []
recursive_dates = np.concatenate([dates_val, dates_test])

# %%
for target_date in recursive_dates:
  last_window = deepcopy(X_train[-1])
  next_prediction = model.predict(np.array([last_window])).flatten()
  recursive_predictions.append(next_prediction)
  last_window[-1] = next_prediction
# Out:
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.plot(recursive_dates, recursive_predictions)
plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations',
            'Recursive Predictions'])
